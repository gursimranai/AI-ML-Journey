# %% [markdown]
# # 📓 Jupyter Notebook Syntax Guide
#
# ---
#
# ## 🎯 Learning Objectives
#
# After completing this notebook, you will be able to:
#
# - Create Markdown cells
# - Create Code cells
# - Format professional documentation
# - Add images, links, tables, and equations
# - Write beautiful Python notes
# - Use HTML inside Markdown
# - Create interactive and readable notebooks
#
# ---
#
# ## What is Jupyter Notebook?
#
# Jupyter Notebook is an interactive computing environment that combines:
#
# - 📖 Documentation (Markdown)
# - 💻 Executable Code
# - 📊 Visualizations
# - 📈 Graphs
# - 📋 Tables
# - 📝 Notes
#
# It is widely used in:
#
# - Data Science
# - Machine Learning
# - Artificial Intelligence
# - Research
# - Education
# - Python Development
#
# ---
#
# ### Notebook consists of two major cell types
#
# 1. Markdown Cell
# 2. Code Cell

# %%
print("Hello Jupyter Notebook!")
# Out:
# Hello Jupyter Notebook!

# %% [markdown]
# ---
#
# # 1. Markdown Cell
#
# Markdown cells are used for writing documentation.
#
# They support:
#
# - Headings
# - Lists
# - Images
# - Links
# - Tables
# - HTML
# - Mathematical Equations
# - Block Quotes
# - Code Blocks
#
# Unlike Code Cells, Markdown cells are **not executed as Python code**.

# %% [markdown]
# # Heading Level 1
#
# ## Heading Level 2
#
# ### Heading Level 3
#
# #### Heading Level 4
#
# ##### Heading Level 5
#
# ###### Heading Level 6

# %% [markdown]
# ## Text Formatting
#
# **Bold**
#
# *Italic*
#
# ***Bold + Italic***
#
# ~~Strikethrough~~
#
# `Inline Code`

# %% [markdown]
# ## Lists
#
# ### Unordered List
#
# - Python
# - Java
# - C++
#
# ### Ordered List
#
# 1. Install Python
# 2. Install Jupyter
# 3. Start Learning

# %%
languages = ["Python", "Java", "C++"]

for language in languages:
    print(language)
# Out:
# Python
# Java
# C++

# %% [markdown]
# ## Block Quote
#
# > Python emphasizes readability.
#
# > Simple is better than complex.

# %% [markdown]
# ## Code Block
#
# ```python
# for i in range(3):
#     print(i)
# ```

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %% [markdown]
# ## Horizontal Line
#
# ---
#
# Everything below the line is separated from the previous section.

# %% [markdown]
# ## Hyperlink
#
# [Python Official Website](https://www.python.org)

# %% [markdown]
# ## Image
#
# ![Python Logo](https://www.python.org/static/community_logos/python-logo.png)

# %% [markdown]
# ## Table
#
# | Language | Creator | Year |
# |----------|---------|------|
# | Python | Guido | 1991 |
# | Java | James Gosling | 1995 |
# | C++ | Bjarne Stroustrup | 1985 |

# %% [markdown]
# students = {
#     "Alice": 90,
#     "Bob": 85,
#     "Charlie": 95
# }
#
# for name, marks in students.items():
#     print(f"{name}: {marks}")

# %% [markdown]
# ## Mathematical Equation
#
# Inline Equation:
#
# $E = mc^2$
#
# Block Equation:
#
# $$
# a^2+b^2=c^2
# $$

# %%
import math

radius = 5

area = math.pi * radius ** 2

print("Area =", area)
# Out:
# Area = 78.53981633974483

# %% [markdown]
# ## HTML in Markdown
#
# <mark>Highlighted Text</mark>
#
# <u>Underlined Text</u>
#
# <sup>Superscript</sup>
#
# <sub>Subscript</sub>
#
# <font color="blue">Blue Text</font>

# %%
name = "Python"
version = 3.14

print(f"Language : {name}")
print(f"Version  : {version}")
# Out:
# Language : Python
# Version  : 3.14

# %% [markdown]
# # 📌 Summary
#
# In this notebook, you learned:
#
# - Markdown Cells
# - Code Cells
# - Headings
# - Lists
# - Tables
# - Images
# - Hyperlinks
# - HTML
# - Mathematical Equations
# - Code Blocks
# - Python Code Execution
#
# These are the essential building blocks for creating professional, readable, and well-documented Jupyter Notebooks.
