# %%
import pandas as pd

# %%
info = {
    "Name" : ["Ram","Sham","Seeta","Geeta","Riya"],
    "CGPA" : [3.5 ,1.2 ,10, 0.9, 9]
}

# %% [markdown]
# # Series
#
# > One - Dimentional Label Array
# >
# > ```Label```= Named Index <br>
# > ```Index```= Position

# %%
data = pd.Series(info)

print(data)
data["Name"][0]
# Out:
# Name    [Ram, Sham, Seeta, Geeta, Riya]
# CGPA             [3.5, 1.2, 10, 0.9, 9]
# dtype: object
# 'Ram'

# %%
data.index
# Out:
# Index(['Name', 'CGPA'], dtype='str')

# %%
df = pd.Series([23,12,34,65,75], index=["Ram","Sham","Geeta","Seeta","Rohit"])

# %%
df
# Out:
# Ram      23
# Sham     12
# Geeta    34
# Seeta    65
# Rohit    75
# dtype: int64

# %% [markdown]
# ## Indexing

# %%
print(df["Ram"])
df.index
# Out:
# 23
# Index(['Ram', 'Sham', 'Geeta', 'Seeta', 'Rohit'], dtype='str')

# %% [markdown]
# # Characteristics
#
# - Homogenious (Same Data Type)
# - Vectorized Operation (No Need Of Loop For Operation Like Add etc)
# - Handling Missing Value with **NaN**
# - Mutable Values , But Size Immutable

# %% [markdown]
# # Data Frame

# %%
data = pd.DataFrame(info , index=range(1,6) )

# %%
data
# Out:
#     Name  CGPA
# 1    Ram   3.5
# 2   Sham   1.2
# 3  Seeta  10.0
# 4  Geeta   0.9
# 5   Riya   9.0

# %%
print(data, type(data))
# Out:
#     Name  CGPA
# 1    Ram   3.5
# 2   Sham   1.2
# 3  Seeta  10.0
# 4  Geeta   0.9
# 5   Riya   9.0 <class 'pandas.DataFrame'>

# %%
data.index
# Out:
# RangeIndex(start=1, stop=6, step=1)

# %%
data.columns
# Out:
# Index(['Name', 'CGPA'], dtype='str')

# %% [markdown]
# ## Creating Data Frame By List Of List

# %%
data = pd.DataFrame([["Ram",12],["Sham",54],["Geeta",65]], columns=["Name","Age"], index=range(1,4))

# %%
data
# Out:
#     Name  Age
# 1    Ram   12
# 2   Sham   54
# 3  Geeta   65

# %%
import numpy as np

# %%
np_arr = np.array([[1,2,3],[4,5,6]])

df = pd.DataFrame(np_arr, columns=["A","B","C"])

# %%
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %% [markdown]
# # Working With CSV And Json Files

# %%
data = pd.read_csv("employee_data.csv")

# %%
data
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
data.head()
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000

# %%
data.tail()
# Out:
#    ID    Name  Age Department  Salary
# 5   6   Frank   29    Finance   50000
# 6   7   Grace   41         HR   82000
# 7   8  Hannah   26  Marketing   47000
# 8   9     Ian   35         IT   75000
# 9  10   Julia   30    Finance   60000

# %%
data.describe()
# Out:
#              ID        Age        Salary
# count  10.00000  10.000000     10.000000
# mean    5.50000  32.900000  64500.000000
# std     3.02765   6.674162  15182.226451
# min     1.00000  25.000000  47000.000000
# 25%     3.25000  28.250000  51250.000000
# 50%     5.50000  31.000000  62500.000000
# 75%     7.75000  37.250000  74250.000000
# max    10.00000  45.000000  91000.000000

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10 non-null     int64
#  1   Name        10 non-null     str
#  2   Age         10 non-null     int64
#  3   Department  10 non-null     str
#  4   Salary      10 non-null     int64
# dtypes: int64(3), str(2)
# memory usage: 532.0 bytes

# %%
data.sample()
# Out:
#    ID Name  Age Department  Salary
# 8   9  Ian   35         IT   75000

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Department', 'Salary'], dtype='str')
