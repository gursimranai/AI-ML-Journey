# %%
# Modules
import math

print(math.sqrt(25))
# Out:
# 5.0

# %%
# Keywords
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# Datetime
import datetime

print(datetime.datetime.now())
# Out:
# 2026-09-05 12:22:30.977294

# %%
# Random
import random

print(random.randint(1,100))
# Out:
# 35

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# IPython             _warnings           idna                random
# PIL                 _weakref            imaplib             re
# __future__          _weakrefset         importlib           referencing
# __hello__           _winapi             inspect             reprlib
# __phello__          _wmi                io                  requests
# _abc                _yaml               ipaddress           rfc3339_validator
# _aix_support        _zoneinfo           ipykernel           rfc3986_validator
# _android_support    _zstd               ipykernel_launcher  rfc3987_syntax
# _apple_support      abc                 ipython_pygments_lexers rlcompleter
# _argon2_cffi_bindings ada92cb5d92a588d1b93__mypyc ipywidgets          rpds
# _ast                annotationlib       isoduration         runpy
# _ast_unparse        antigravity         itertools           sched
# ...

# %%
# Number Guessing Game
import random

guess = int(input("Guess The Number : "))

jackpot = random.randint(1,100)
counter = 1
while guess != jackpot :
    if guess > jackpot :
        print("Lala! Chota number sotcho")
    else :
        print("Lala! Bada number sotcho")
    

    guess = int(input("Guess The Number : "))
    counter += 1
else :
        print("Lala! Jiit Gaye tum !")
        print("Attemps: ",counter)
# Out:
# Lala! Chota number sotcho
# Lala! Bada number sotcho
# Lala! Bada number sotcho
# Lala! Bada number sotcho
# Lala! Jiit Gaye tum !
# Attemps:  5

# %% [markdown]
# - **Program:** Current poppulation of the town is 10,000. the poppulation of the town increasing at the rate of 10% per years. you have to write the program to find out the population at the end of the each of the last 10 years.

# %%
curr_popul = 10000
for year in range(10,0,-1):
    print(year,curr_popul)
    curr_popul = curr_popul - 0.1*curr_popul
# Out:
# 10 10000
# 9 9000.0
# 8 8100.0
# 7 7290.0
# 6 6561.0
# 5 5904.9
# 4 5314.41
# 3 4782.969
# 2 4304.6721
# 1 3874.20489
