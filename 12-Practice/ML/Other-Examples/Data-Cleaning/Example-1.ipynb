# %% [markdown]
# # Import Useful Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Dataset

# %%
url = "https://people.sc.fsu.edu/~jburkardt/data/csv/hw_200.csv"
df = pd.read_csv(url)
df.columns = ["Index", "Height", "Weight"]

# %%
df
# Out:
#      Index  Height  Weight
# 0        1   65.78  112.99
# 1        2   71.52  136.49
# 2        3   69.40  153.03
# 3        4   68.22  142.34
# 4        5   67.79  144.30
# ..     ...     ...     ...
# 195    196   65.80  120.84
# 196    197   66.11  115.78
# 197    198   68.24  128.30
# 198    199   68.02  127.47
# 199    200   71.39  127.88
#
# [200 rows x 3 columns]

# %%
# Data set Summary

print(df.describe())
# Out:
#             Index      Height      Weight
# count  200.000000  200.000000  200.000000
# mean   100.500000   67.949800  127.221950
# std     57.879185    1.940363   11.960959
# min      1.000000   63.430000   97.900000
# 25%     50.750000   66.522500  119.895000
# 50%    100.500000   67.935000  127.875000
# 75%    150.250000   69.202500  136.097500
# max    200.000000   73.900000  158.960000

# %% [markdown]
# # Creating Visualization

# %%
# Scatter plot
plt.figure(figsize=(8,6))
plt.scatter(df["Height"],df["Weight"],color='blue', alpha=0.5,)
plt.title("Height vs Weight",fontsize=16)
plt.xlabel("Height (inches)",fontsize=12)
plt.ylabel("Weight (pounds)",fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # Handle missing value

# %%
# if df.isnull().values.any():
#     df.fillna(df.mean(),inplace =True)

# %%
# Second Way to check for missing values and fill them with mean
df.isnull().sum()
# Out:
# Index     0
# Height    0
# Weight    0
# dtype: int64

# %%
# there are no missing values in the dataset, so we don't need to fill any values with mean.
# if any column had missing values, we could fill them with the mean of that column using the following code:
df['Index'] = df["Index"].fillna(df["Index"].mean())

# %% [markdown]
# # Adding New Column

# %%
df["BMI"] = df["Weight"] / (df["Height"] / 39.37) ** 2

# %%
print(df.head())
# Out:
#    Index  Height  Weight        BMI
# 0      1   65.78  112.99  40.474650
# 1      2   71.52  136.49  41.359631
# 2      3   69.40  153.03  49.247985
# 3      4   68.22  142.34  47.406114
# 4      5   67.79  144.30  48.670510

# %%
# This Regression plot will show the relationship between Height and Weight,
# along with a regression line that best fits the data points. (Study Latter)
# The scatter points will be in blue, and the regression line will be in red.

sns.regplot(
    x="Height",
    y="Weight",
    data=df,
    scatter_kws={"color": "blue"},
    line_kws={"color": "red"}
)

plt.title("Height vs Weight with Regression Line")

# Saving plot tight is used to ensure that the saved image does not have any extra whitespace around it.
plt.savefig(
    "Height_vs_weight_plot_with_regression.png",
    dpi=300,
    bbox_inches="tight"
)
plt.show()

# %%
sns.scatterplot(x="Height", y="Weight", data=df)

plt.title("Height vs Weight")

plt.savefig(
    "Height_vs_weight_plot.png"
)
plt.show()

# %%
df.to_csv("cleaned_data.csv", index=False)
